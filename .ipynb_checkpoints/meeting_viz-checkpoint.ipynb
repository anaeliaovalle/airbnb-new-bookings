# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
pd.set_option("display.max_rows", 16) 
sns.set_style("darkgrid")
LARGE_FIGSIZE = (12, 8)
from sklearn import tree
import datetime as dt

# %%
filename = "meeting.csv"
# ?pd.read_table
# ?pd.read_csv
data = pd.read_csv(filename)
# ?pd.to_datetime
data.head()
# Out:
#          date
# 0  09/26/2016
# 1  09/30/2016
# 2  10/03/2016
# 3  10/10/2016
# 4  10/17/2016

# %%
pd.to_datetime(data['date'],format='%m/%d/%Y')
data['day'] = data['date'].dt.weekday_name
print data.day
data['month'] = data['date'].dt.month
# Out:
# 0        Monday
# 1        Friday
# 2        Monday
# 3        Monday
# 4        Monday
# 5        Monday
# 6        Monday
# 7        Friday
# 8        Monday
# 9        Sunday
# 10    Wednesday
# 11       Friday
# 12       Sunday
# 13      Tuesday
# 14       Sunday
# 15      Tuesday
# Name: day, dtype: object

# %%
plot= sns.countplot(x='day', data=data)
plt.title("Team Meeting Days")
# plot.set_xlabel(labels)
plt.xlabel('Day of the Week')

# %%
data['day'] = data['date'].dt.weekday
plot =sns.distplot(data.day, bins =5 )
plt.title('Meeting Days')
sns.plt.show()

# %%
plt.title('Meeting Days')
plt.plot(data.day)

# %%
plt.plot(data.month)
plt.title('Meeting Month')

# %%
ts = Series(randn(1000), index=date_range('1/1/2000', periods=1000))

ts = ts.cumsum()

ts.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-135-b39bef79063c> in <module>()
# ----> 1 ts = Series(randn(1000), index=date_range('1/1/2000', periods=1000))
#       2
#       3 ts = ts.cumsum()
#       4
#       5 ts.plot()
#
# NameError: name 'Series' is not defined
